# %%
#!pip install scikit-learn
import pip
pip.main(['install','scikit-learn'])
import sklearn
# Out:
# WARNING: pip is being invoked by an old script wrapper. This will fail in a future version of pip.
# Please see https://github.com/pypa/pip/issues/5599 for advice on fixing the underlying issue.
# To avoid this problem you can invoke Python with '-m pip' instead of running pip directly.
# Requirement already satisfied: scikit-learn in c:\users\azal\appdata\local\programs\python\python313\lib\site-packages (1.6.1)
# Requirement already satisfied: numpy>=1.19.5 in c:\users\azal\appdata\local\programs\python\python313\lib\site-packages (from scikit-learn) (2.2.3)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\azal\appdata\local\programs\python\python313\lib\site-packages (from scikit-learn) (1.15.2)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\azal\appdata\local\programs\python\python313\lib\site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\azal\appdata\local\programs\python\python313\lib\site-packages (from scikit-learn) (3.5.0)

# %%
import pandas as pd
from sklearn.tree import DecisionTreeClassifier
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn import tree
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## Loading Data

# %%
df = pd.read_csv('vehicles.csv')
df.head(8)
# df
# Out:
#    Age  Gender  Income Favorite Transport
# 0    5  female     NaN            bicycle
# 1    8    male     NaN            scooter
# 2   10  female     NaN            bicycle
# 3   14    male     NaN              metro
# 4   16    male     NaN              metro
# 5   18  female     NaN              metro
# 6   20    male   200.0            scooter
# 7   22  female   500.0            scooter

# %%
df.dtypes
# Out:
# Age                     int64
# Gender                 object
# Income                float64
# Favorite Transport     object
# dtype: object

# %% [markdown]
# ## Cleaning

# %%
df.isnull().sum()
# Out:
# Age                   0
# Gender                0
# Income                6
# Favorite Transport    0
# dtype: int64

# %%
df['Income'].fillna(0.0, inplace=True)
df.head()
# Out:
# C:\Users\Azal\AppData\Local\Temp\ipykernel_13644\1539436780.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Income'].fillna(0.0, inplace=True)
#    Age  Gender  Income Favorite Transport
# 0    5  female     0.0            bicycle
# 1    8    male     0.0            scooter
# 2   10  female     0.0            bicycle
# 3   14    male     0.0              metro
# 4   16    male     0.0              metro

# %%
df.isnull().sum()
# Out:
# Age                   0
# Gender                0
# Income                0
# Favorite Transport    0
# dtype: int64

# %% [markdown]
# ## Encoding

# %%
df['Gender'].unique()
# Out:
# array(['female', 'male'], dtype=object)

# %%
# df.replace({
#     'Gender':{
#         'male':0,
#         'female': 1
#     }
# }, inplace=True)
# df.head(5)

# OPTION 2
label_encoder = LabelEncoder()
df['Gender'] = label_encoder.fit_transform(df['Gender'])
df.head(8)
# Out:
#    Age  Gender  Income Favorite Transport
# 0    5       0     0.0            bicycle
# 1    8       1     0.0            scooter
# 2   10       0     0.0            bicycle
# 3   14       1     0.0              metro
# 4   16       1     0.0              metro
# 5   18       0     0.0              metro
# 6   20       1   200.0            scooter
# 7   22       0   500.0            scooter

# %% [markdown]
# ## Model

# %%
X = df.drop(columns = 'Favorite Transport')
X.head(3)
# Out:
#    Age  Gender  Income
# 0    5       0     0.0
# 1    8       1     0.0
# 2   10       0     0.0

# %%
df.dtypes
# Out:
# Age                     int64
# Gender                  int64
# Income                float64
# Favorite Transport     object
# dtype: object

# %%
y = df['Favorite Transport']
y.head(3)
# Out:
# 0    bicycle
# 1    scooter
# 2    bicycle
# Name: Favorite Transport, dtype: object

# %%
model = DecisionTreeClassifier()
model
# Out:
# DecisionTreeClassifier()

# %%
model.fit(X, y)
# Out:
# DecisionTreeClassifier()

# %% [markdown]
# ## Prediction

# %%
test_df = pd.DataFrame({
    'Age': [12, 30, 75],
    'Gender': [0, 0, 1],
    'Income': [0.0, 4000, 50000]
})
test_df
# Out:
#    Age  Gender   Income
# 0   12       0      0.0
# 1   30       0   4000.0
# 2   75       1  50000.0

# %%
model.predict(test_df)
# Out:
# array(['bicycle', 'car', 'helicopter'], dtype=object)

# %% [markdown]
# ## Exporting to the DOT file

# %%
tree.export_graphviz(model, out_file='decision_tree_model.dot', feature_names=['Age', 'Gender', 'Income'], filled=True, class_names=sorted(y.unique()))

# %% [markdown]
# ## Evaluation

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1)

X.shape
# Out:
# (26, 3)

# %%
X_train.shape
# Out:
# (23, 3)

# %%
X_test.shape
# Out:
# (3, 3)

# %%
model = DecisionTreeClassifier()
model.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
predictions = model.predict(X_test)
predictions
# Out:
# array(['scooter', 'helicopter', 'taxi'], dtype=object)

# %%
model_accuracy_score = accuracy_score(y_test, predictions)
model_accuracy_score
# Out:
# 1.0

# %% [markdown]
# ## Charts

# %%
sns.countplot(x=df['Gender'], hue=df['Favorite Transport'])
plt.show()
# Out:
# Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.

# %%
sns.histplot(x=df['Income'], hue=df['Favorite Transport'])
plt.show()
