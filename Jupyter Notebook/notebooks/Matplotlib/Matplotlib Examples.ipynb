# %%
import pip
pip.main(['install','seaborn'])
# Out:
# WARNING: pip is being invoked by an old script wrapper. This will fail in a future version of pip.
# Please see https://github.com/pypa/pip/issues/5599 for advice on fixing the underlying issue.
# To avoid this problem you can invoke Python with '-m pip' instead of running pip directly.
# Collecting seaborn
#   Using cached seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\azal\appdata\local\programs\python\python313\lib\site-packages (from seaborn) (2.2.3)
# Requirement already satisfied: pandas>=1.2 in c:\users\azal\appdata\local\programs\python\python313\lib\site-packages (from seaborn) (2.2.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\users\azal\appdata\local\programs\python\python313\lib\site-packages (from seaborn) (3.10.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\azal\appdata\local\programs\python\python313\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\azal\appdata\local\programs\python\python313\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\azal\appdata\local\programs\python\python313\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\azal\appdata\local\programs\python\python313\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\azal\appdata\local\programs\python\python313\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (24.2)
# Requirement already satisfied: pillow>=8 in c:\users\azal\appdata\local\programs\python\python313\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\azal\appdata\local\programs\python\python313\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\azal\appdata\local\programs\python\python313\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\azal\appdata\local\programs\python\python313\lib\site-packages (from pandas>=1.2->seaborn) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\azal\appdata\local\programs\python\python313\lib\site-packages (from pandas>=1.2->seaborn) (2025.1)
# Requirement already satisfied: six>=1.5 in c:\users\azal\appdata\local\programs\python\python313\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)
# Using cached seaborn-0.13.2-py3-none-any.whl (294 kB)
# Installing collected packages: seaborn
# Successfully installed seaborn-0.13.2
# 0

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
values = [0, 1, 2, 3, 4, 5, 6, 7]
squares = [value ** 2 for value in values]
squares
# Out:
# [0, 1, 4, 9, 16, 25, 36, 49]

# %%
plt.plot(values, squares)
plt.show()

# %%
plt.scatter(values, squares)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
values = list(range(100))
pows = [pow(value, 3) for value in values]
plt.scatter(values, pows)
plt.show()

# %%
plt.scatter(values, pows, c=pows, cmap=plt.cm.Blues, edgecolor='none', s=10)
plt.show()

# %%
values = list(range(50))
squares = [pow(value, 2) for value in values]
cubes = [pow(value, 3) for value in values]

fig, (ax1, ax2) = plt.subplots(2, 1, sharex= True)
ax1.scatter(values, squares)
ax1.set_title('Square numbers')
ax2.plot(values, cubes)
ax2.set_title('Cube numbers')
plt.show()

# %%
values = list(range(10))
squares = [pow(value, 2) for value in values]
cubes = [pow(value, 3) for value in values]

fig, (ax1, ax2) = plt.subplots(1, 2, sharey= True)
ax1.scatter(values, squares)
ax1.set_title('Square numbers')
ax2.plot(values, cubes)
ax2.set_title('Cube numbers')
plt.show()

# %%
data = {
    'Year': [2001, 2002, 2003, 2004, 2005, 2006],
    'Sales': [100, 150, 130, 180, 210, 230]
}

df = pd.DataFrame(data)
df.plot(x='Year', y='Sales', kind='line')
plt.title('Yearly Sales')
plt.show()

# %%
data = {
    'Year': [2001, 2002, 2003, 2004, 2005, 2006],
    'Sales': [100, 150, 130, 180, 210, 230]
}

df = pd.DataFrame(data)
df.plot(y='Sales', kind='pie', labels=df['Year'], autopct='%1.1f%%')
plt.title('Yearly Sales')
plt.show()

# %%
data = {
    'Age': [25, 28, 32, 41, 42, 42, 50, 59, 60]
}

df = pd.DataFrame(data)
df.plot(y='Age', kind='hist')
plt.title('Age distribution')
plt.show()

# %%
data = {
    'Category': ['FIRST', 'FIRST', 'SECOND', 'SECOND', 'THIRD', 'THIRD', 'SECOND'],
    'Value': [10, 20, 25, 45, 45, 50, 50]
}

df = pd.DataFrame(data)
df
# Out:
#   Category  Value
# 0    FIRST     10
# 1    FIRST     20
# 2   SECOND     25
# 3   SECOND     45
# 4    THIRD     45
# 5    THIRD     50
# 6   SECOND     50

# %%
df.boxplot(by='Category', column='Value')
plt.title('Values distribution by category')
plt.show()

# %%
data = {
    'Month': ['Jan', 'Fab', 'Mar', 'Apr', 'May'],
    'Week 1 Temp': [6, 10, 12, 14, 17],
    'Week 2 Temp': [8, 12, 13, 14, 18],
    'Week 3 Temp': [9, 11, 14, 16, 20],
    'Week 4 Temp': [10, 15, 10, 17, 22],
}

df = pd.DataFrame(data)
df.head()
# Out:
#   Month  Week 1 Temp  Week 2 Temp  Week 3 Temp  Week 4 Temp
# 0   Jan            6            8            9           10
# 1   Fab           10           12           11           15
# 2   Mar           12           13           14           10
# 3   Apr           14           14           16           17
# 4   May           17           18           20           22

# %%
df.set_index('Month', inplace=True)
df.head()
# Out:
#        Week 1 Temp  Week 2 Temp  Week 3 Temp  Week 4 Temp
# Month
# Jan              6            8            9           10
# Fab             10           12           11           15
# Mar             12           13           14           10
# Apr             14           14           16           17
# May             17           18           20           22

# %%
sns.heatmap(df, cmap='coolwarm', annot=True)
plt.title('Weekly temperature data')
plt.show()
